# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import kurtosis, skew, pearsonr, linregress
import numpy as np
import math

# %matplotlib inline

# %%
df = sns.load_dataset("anscombe")

df.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
df1 = df[df['dataset'] == 'I']
df1 = df1.drop(columns = ['dataset'])
df2 = df[df['dataset'] == 'II']
df2 = df2.drop(columns = ['dataset'])
df3 = df[df['dataset'] == 'III']
df3 = df3.drop(columns = ['dataset'])
df4 = df[df['dataset'] == 'IV']
df4 = df4.drop(columns = ['dataset'])

# %%
df1.T.shape
# Out:
# (2, 11)

# %%
from SimAnn import SimulatedAnnealing
test1 = SimulatedAnnealing(iters = 200)
test1.run()
# Out:
# on iteration: 0
# on iteration: 1
# on iteration: 2
# on iteration: 3
# on iteration: 4
# on iteration: 5
# on iteration: 6
# on iteration: 7
# on iteration: 8
# on iteration: 9
# on iteration: 10
# on iteration: 11
# on iteration: 12
# on iteration: 13
# on iteration: 14
# on iteration: 15
# on iteration: 16
# on iteration: 17
# on iteration: 18
# on iteration: 19
# on iteration: 20
# on iteration: 21
# on iteration: 22
# on iteration: 23
# on iteration: 24
# on iteration: 25
# on iteration: 26
# on iteration: 27
# on iteration: 28
# on iteration: 29
# on iteration: 30
# on iteration: 31
# on iteration: 32
# on iteration: 33
# on iteration: 34
# on iteration: 35
# on iteration: 36
# on iteration: 37
# on iteration: 38
# on iteration: 39
# on iteration: 40
# on iteration: 41
# on iteration: 42
# on iteration: 43
# on iteration: 44
# on iteration: 45
# on iteration: 46
# on iteration: 47
# on iteration: 48
# on iteration: 49
# on iteration: 50
# on iteration: 51
# on iteration: 52
# ...

# %%
from SimAnn import SimulatedAnnealing
test2 = SimulatedAnnealing(iters = 200)
test2.run()
# Out:
# on iteration: 0
# on iteration: 1
# on iteration: 2
# on iteration: 3
# on iteration: 4
# on iteration: 5
# on iteration: 6
# on iteration: 7
# on iteration: 8
# on iteration: 9
# on iteration: 10
# on iteration: 11
# on iteration: 12
# on iteration: 13
# on iteration: 14
# on iteration: 15
# on iteration: 16
# on iteration: 17
# on iteration: 18
# on iteration: 19
# on iteration: 20
# on iteration: 21
# on iteration: 22
# on iteration: 23
# on iteration: 24
# on iteration: 25
# on iteration: 26
# on iteration: 27
# on iteration: 28
# on iteration: 29
# on iteration: 30
# on iteration: 31
# on iteration: 32
# on iteration: 33
# on iteration: 34
# on iteration: 35
# on iteration: 36
# on iteration: 37
# on iteration: 38
# on iteration: 39
# on iteration: 40
# on iteration: 41
# on iteration: 42
# on iteration: 43
# on iteration: 44
# on iteration: 45
# on iteration: 46
# on iteration: 47
# on iteration: 48
# on iteration: 49
# on iteration: 50
# on iteration: 51
# on iteration: 52
# ...

# %%
from SimAnn import SimulatedAnnealing
test3 = SimulatedAnnealing(iters = 200)
test3.run()
# Out:
# on iteration: 0
# on iteration: 1
# on iteration: 2
# on iteration: 3
# on iteration: 4
# on iteration: 5
# on iteration: 6
# on iteration: 7
# on iteration: 8
# on iteration: 9
# on iteration: 10
# on iteration: 11
# on iteration: 12
# on iteration: 13
# on iteration: 14
# on iteration: 15
# on iteration: 16
# on iteration: 17
# on iteration: 18
# on iteration: 19
# on iteration: 20
# on iteration: 21
# on iteration: 22
# on iteration: 23
# on iteration: 24
# on iteration: 25
# on iteration: 26
# on iteration: 27
# on iteration: 28
# on iteration: 29
# on iteration: 30
# on iteration: 31
# on iteration: 32
# on iteration: 33
# on iteration: 34
# on iteration: 35
# on iteration: 36
# on iteration: 37
# on iteration: 38
# on iteration: 39
# on iteration: 40
# on iteration: 41
# on iteration: 42
# on iteration: 43
# on iteration: 44
# on iteration: 45
# on iteration: 46
# on iteration: 47
# on iteration: 48
# on iteration: 49
# on iteration: 50
# on iteration: 51
# on iteration: 52
# ...

# %%
from SimAnn import SimulatedAnnealing
test4 = SimulatedAnnealing(iters = 200)
test4.run()
# Out:
# on iteration: 0
# on iteration: 1
# on iteration: 2
# on iteration: 3
# on iteration: 4
# on iteration: 5
# on iteration: 6
# on iteration: 7
# on iteration: 8
# on iteration: 9
# on iteration: 10
# on iteration: 11
# on iteration: 12
# on iteration: 13
# on iteration: 14
# on iteration: 15
# on iteration: 16
# on iteration: 17
# on iteration: 18
# on iteration: 19
# on iteration: 20
# on iteration: 21
# on iteration: 22
# on iteration: 23
# on iteration: 24
# on iteration: 25
# on iteration: 26
# on iteration: 27
# on iteration: 28
# on iteration: 29
# on iteration: 30
# on iteration: 31
# on iteration: 32
# on iteration: 33
# on iteration: 34
# on iteration: 35
# on iteration: 36
# on iteration: 37
# on iteration: 38
# on iteration: 39
# on iteration: 40
# on iteration: 41
# on iteration: 42
# on iteration: 43
# on iteration: 44
# on iteration: 45
# on iteration: 46
# on iteration: 47
# on iteration: 48
# on iteration: 49
# on iteration: 50
# on iteration: 51
# on iteration: 52
# ...

# %%
from SimAnn import SimulatedAnnealing
test5 = SimulatedAnnealing(iters = 200)
test5.run()
# Out:
# on iteration: 0
# on iteration: 1
# on iteration: 2
# on iteration: 3
# on iteration: 4
# on iteration: 5
# on iteration: 6
# on iteration: 7
# on iteration: 8
# on iteration: 9
# on iteration: 10
# on iteration: 11
# on iteration: 12
# on iteration: 13
# on iteration: 14
# on iteration: 15
# on iteration: 16
# on iteration: 17
# on iteration: 18
# on iteration: 19
# on iteration: 20
# on iteration: 21
# on iteration: 22
# on iteration: 23
# on iteration: 24
# on iteration: 25
# on iteration: 26
# on iteration: 27
# on iteration: 28
# on iteration: 29
# on iteration: 30
# on iteration: 31
# on iteration: 32
# on iteration: 33
# on iteration: 34
# on iteration: 35
# on iteration: 36
# on iteration: 37
# on iteration: 38
# on iteration: 39
# on iteration: 40
# on iteration: 41
# on iteration: 42
# on iteration: 43
# on iteration: 44
# on iteration: 45
# on iteration: 46
# on iteration: 47
# on iteration: 48
# on iteration: 49
# on iteration: 50
# on iteration: 51
# on iteration: 52
# ...

# %%
ds1 = test1.op_ds
ds2 = test2.op_ds
ds3 = test3.op_ds
ds4 = test4.op_ds
ds5 = test5.op_ds

# %%
ds1_ = np.insert(ds1,2,1, axis = 0)
ds2_ = np.insert(ds2,2,2, axis = 0)
ds3_ = np.insert(ds3,2,3, axis = 0)
ds4_ = np.insert(ds4,2,4, axis = 0)
ds5_ = np.insert(ds5,2,5, axis = 0)

gen_ds = np.concatenate((ds1_, ds2_, ds3_, ds4_, ds5_), axis= 1)

# %%
coeffz = np.polyfit(gen_ds[0], gen_ds[1], 1)

# %%
print(gen_ds[0])
# Out:
# [11.58024975  4.12020867  8.30371611  6.37606886  4.03681539  7.77841655
#  10.23400532 13.94681904 13.7165272   8.75527527 10.45605618  4.03004527
#  13.68949579  6.31702049 10.51922113  5.81845403  9.06369135 12.77012466
#   9.67014025  4.64888357  8.91248069 13.57622491  5.03519189  5.21795118
#  13.84503808 10.32263046 11.45013881 12.92842167  9.51412243  5.69620223
#  12.89261337  5.83878692  6.25368733 13.01700308 12.26786967 12.82415312
#   6.405898    9.26465373  5.54752246  6.19213194 13.8720071   6.28839548
#   4.32850265  8.9901528  13.9709596   4.01822226  6.08911682  4.36463998
#  11.8915199  11.22720715  6.81266795 12.74330253  8.30954618  7.82602596
#  11.74623235]

# %%
def dissimilarity(ds1, ds2):
    one = np.array(ds1)
    two = np.array(ds2)
    diff_x = np.sum(np.abs(one[0,:]- two[0,:]))
    diff_y = np.sum(np.abs(one[1,:]- two[1,:]))

    return (diff_x + diff_y)


print(round(dissimilarity(ds4, ds5)))
# Out:
# 62.0

# %%
new_df.boxplot(by='dataset', column =['x','y'], grid = False)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a287f89d0>,
# ...
#       dtype=object)

# %%
df1.head()
# Out:
#       x     y
# 0  10.0  8.04
# 1   8.0  6.95
# 2  13.0  7.58
# 3   9.0  8.81
# 4  11.0  8.33

# %%
sumstat1 = test1.get_sum_stats(ds1[0,:], ds1[1,:])
sumstat2 = test1.get_sum_stats(ds2[0,:], ds2[1,:])
sumstat3 = test1.get_sum_stats(ds3[0,:], ds3[1,:])
sumstat4 = test1.get_sum_stats(ds4[0,:], ds4[1,:])
sumstat5 = test1.get_sum_stats(ds5[0,:], ds5[1,:])

# %%
std = np.array([sumstat1[-2], sumstat2[1], sumstat3[1], sumstat4[1], sumstat5[1]])
mean_std = np.mean(std)

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(ds1[0,:], ds1[1,:])
ax.scatter(ds2[0,:], ds2[1,:])
ax.scatter(ds3[0,:], ds3[1,:])
ax.scatter(ds4[0,:], ds4[1,:])
ax.scatter(ds5[0,:], ds5[1,:])
poly1d_fn = np.poly1d(coeffz) 
ax.plot(gen_ds[0], poly1d_fn(gen_ds[0]), color='black')

ax.legend(['Reg line','DS 1','DS 2','DS 3','DS 4','DS 5'])

plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
test1.get_sum_stats(ds1[0,:], ds1[1,:])
# Out:
# array([9.02765076, 3.22456962, 7.41475407, 2.02625227, 0.77765792,
#        0.48866401, 3.00326601, 0.60475185])

# %%
print("Hello")
# Out:
# Hello

# %%
test6 = SimulatedAnnealing(iters=215)
test6.run()
# Out:
# on iteration: 0
# on iteration: 1
# on iteration: 2
# on iteration: 3
# on iteration: 4
# on iteration: 5
# on iteration: 6
# on iteration: 7
# on iteration: 8
# on iteration: 9
# on iteration: 10
# on iteration: 11
# on iteration: 12
# on iteration: 13
# on iteration: 14
# on iteration: 15
# on iteration: 16
# on iteration: 17
# on iteration: 18
# on iteration: 19
# on iteration: 20
# on iteration: 21
# on iteration: 22
# on iteration: 23
# on iteration: 24
# on iteration: 25
# on iteration: 26
# on iteration: 27
# on iteration: 28
# on iteration: 29
# on iteration: 30
# on iteration: 31
# on iteration: 32
# on iteration: 33
# on iteration: 34
# on iteration: 35
# on iteration: 36
# on iteration: 37
# on iteration: 38
# on iteration: 39
# on iteration: 40
# on iteration: 41
# on iteration: 42
# on iteration: 43
# on iteration: 44
# on iteration: 45
# on iteration: 46
# on iteration: 47
# on iteration: 48
# on iteration: 49
# on iteration: 50
# on iteration: 51
# on iteration: 52
# ...

# %%
test7 = SimulatedAnnealing(iters=215)
test7.run()
# Out:
# on iteration: 0
# on iteration: 1
# on iteration: 2
# on iteration: 3
# on iteration: 4
# on iteration: 5
# on iteration: 6
# on iteration: 7
# on iteration: 8
# on iteration: 9
# on iteration: 10
# on iteration: 11
# on iteration: 12
# on iteration: 13
# on iteration: 14
# on iteration: 15
# on iteration: 16
# on iteration: 17
# on iteration: 18
# on iteration: 19
# on iteration: 20
# on iteration: 21
# on iteration: 22
# on iteration: 23
# on iteration: 24
# on iteration: 25
# on iteration: 26
# on iteration: 27
# on iteration: 28
# on iteration: 29
# on iteration: 30
# on iteration: 31
# on iteration: 32
# on iteration: 33
# on iteration: 34
# on iteration: 35
# on iteration: 36
# on iteration: 37
# on iteration: 38
# on iteration: 39
# on iteration: 40
# on iteration: 41
# on iteration: 42
# on iteration: 43
# on iteration: 44
# on iteration: 45
# on iteration: 46
# on iteration: 47
# on iteration: 48
# on iteration: 49
# on iteration: 50
# on iteration: 51
# on iteration: 52
# ...

# %%
test8 = SimulatedAnnealing(iters=218)
test8.run()
# Out:
# on iteration: 0
# on iteration: 1
# on iteration: 2
# on iteration: 3
# on iteration: 4
# on iteration: 5
# on iteration: 6
# on iteration: 7
# on iteration: 8
# on iteration: 9
# on iteration: 10
# on iteration: 11
# on iteration: 12
# on iteration: 13
# on iteration: 14
# on iteration: 15
# on iteration: 16
# on iteration: 17
# on iteration: 18
# on iteration: 19
# on iteration: 20
# on iteration: 21
# on iteration: 22
# on iteration: 23
# on iteration: 24
# on iteration: 25
# on iteration: 26
# on iteration: 27
# on iteration: 28
# on iteration: 29
# on iteration: 30
# on iteration: 31
# on iteration: 32
# on iteration: 33
# on iteration: 34
# on iteration: 35
# on iteration: 36
# on iteration: 37
# on iteration: 38
# on iteration: 39
# on iteration: 40
# on iteration: 41
# on iteration: 42
# on iteration: 43
# on iteration: 44
# on iteration: 45
# on iteration: 46
# on iteration: 47
# on iteration: 48
# on iteration: 49
# on iteration: 50
# on iteration: 51
# on iteration: 52
# ...

# %%
ds8  = test8.op_ds
test1.get_sum_stats(ds8[0,:], ds8[1,:])
# Out:
# array([9.00005525, 3.31687246, 7.50123081, 2.03156247, 0.81654621,
#        0.50012916, 3.00004073, 0.66674772])

# %%
ds7  = test7.op_ds
test1.get_sum_stats(ds7[0,:], ds7[1,:])
# Out:
# array([9.00013895, 3.31504225, 7.50096973, 2.03033026, 0.8165877 ,
#        0.50012718, 2.99975565, 0.66681547])

# %%
ds6  = test6.op_ds
test1.get_sum_stats(ds6[0,:], ds6[1,:])
# Out:
# array([9.00038471, 3.31608977, 7.50121   , 2.03508477, 0.81513519,
#        0.50024858, 2.99878031, 0.66444537])

# %%
test1.get_sum_stats(ds4[0,:], ds4[1,:])
# Out:
# array([8.99984455, 3.31600527, 7.50202801, 2.03246691, 0.81602162,
#        0.50016113, 3.00065561, 0.66589128])

# %%
test9 = SimulatedAnnealing(iters=215)
test9.run()
# Out:
# on iteration: 0
# on iteration: 1
# on iteration: 2
# on iteration: 3
# on iteration: 4
# on iteration: 5
# on iteration: 6
# on iteration: 7
# on iteration: 8
# on iteration: 9
# on iteration: 10
# on iteration: 11
# on iteration: 12
# on iteration: 13
# on iteration: 14
# on iteration: 15
# on iteration: 16
# on iteration: 17
# on iteration: 18
# on iteration: 19
# on iteration: 20
# on iteration: 21
# on iteration: 22
# on iteration: 23
# on iteration: 24
# on iteration: 25
# on iteration: 26
# on iteration: 27
# on iteration: 28
# on iteration: 29
# on iteration: 30
# on iteration: 31
# on iteration: 32
# on iteration: 33
# on iteration: 34
# on iteration: 35
# on iteration: 36
# on iteration: 37
# on iteration: 38
# on iteration: 39
# on iteration: 40
# on iteration: 41
# on iteration: 42
# on iteration: 43
# on iteration: 44
# on iteration: 45
# on iteration: 46
# on iteration: 47
# on iteration: 48
# on iteration: 49
# on iteration: 50
# on iteration: 51
# on iteration: 52
# ...

# %%
error = test9._ERROR
plt.plot(np.log10(error))
plt.xlabel(" Iteration ")
plt.ylabel(" Log_10(error) ")
# Out:
# Text(0, 0.5, ' Log_10(error) ')

# %%
error = test9._ERROR
plt.plot(error)
plt.xlabel(" Iteration ")
plt.ylabel(" error ")
# Out:
# Text(0, 0.5, ' error ')
